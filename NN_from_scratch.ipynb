# %% [markdown]
# Neural Network from Scratch - Using the dataset MNIST

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
class DenseLayer:

    def __init__(self,input_array_x,units):
        n_inputs = len(input_array_x)

        self.weights = np.random.randn(n_inputs,units)*0.1
        self.biases = np.zeros((1, units))


    def dense_layer_foward_propagation(self, input_array_x):
        '''Dados um array de entrada e uma layer, retorna a saída dessa layers'''
        self.output = (input_array_x @ self.weights + self.biases).ReLU()
        return self.output


class NNModel:

    def __init__(self):
        self.layers = []


    def ReLU(self):
        return np.maximum(0,self)


    def build_model(self):
        pass

    def add_layer_dense(self, layer):
        #layer é um objeto DenseLayer
        self.layers.append(layer)






    def foward_propagation(self, input_array_x):
        for layer in self.layers:
            input_array_x = layer.dense_layer_foward_propagation(input_array_x,layer)
        return input_array_x

    def backpropagation(self):
